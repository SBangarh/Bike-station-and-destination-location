# %% [markdown]
# # CityBikes

# %%
pip install python-citybikes
# Out:
# Requirement already satisfied: python-citybikes in /home/sbangarh/anaconda3/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: requests in /home/sbangarh/anaconda3/lib/python3.11/site-packages (from python-citybikes) (2.31.0)
# Requirement already satisfied: six in /home/sbangarh/anaconda3/lib/python3.11/site-packages (from python-citybikes) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sbangarh/anaconda3/lib/python3.11/site-packages (from requests->python-citybikes) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sbangarh/anaconda3/lib/python3.11/site-packages (from requests->python-citybikes) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sbangarh/anaconda3/lib/python3.11/site-packages (from requests->python-citybikes) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sbangarh/anaconda3/lib/python3.11/site-packages (from requests->python-citybikes) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# PLEASE NOTE THAT THIS PROJECT WAS POSSIBLE BECAUSE OF CITYBIKES. THEIR API DOCUMENTATION PAGE CAN BE FOUND HERE: http://api.citybik.es/v2/

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import requests
import pandas as pd
from pprint import pprint

url = "http://api.citybik.es/v2/networks/mobibikes"
citybikes = requests.get(url)
cb_data = citybikes.json()
pprint(cb_data)
# Out:
# {'network': {'company': ['Vanncouver Bike Share Inc.',
#                          'CycleHop LLC',
#                          'City of Vancouver',
#                          'Shaw Communications Inc.',
#                          'Fifteen'],
#              'gbfs_href': 'https://vancouver-gbfs.smoove.pro/gbfs/2/gbfs.json',
#              'href': '/v2/networks/mobibikes',
#              'id': 'mobibikes',
#              'location': {'city': 'Vancouver',
#                           'country': 'CA',
#                           'latitude': 49.2827,
#                           'longitude': -123.1207},
#              'name': 'Mobi',
#              'stations': [{'empty_slots': 19,
#                            'extra': {'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834865,
#                                      'normal_bikes': 14,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '0001'},
#                            'free_bikes': 17,
#                            'id': '7a19c49f486d7c0c02b3685d7b240448',
#                            'latitude': 49.262487,
#                            'longitude': -123.114397,
#                            'name': '10th & Cambie',
#                            'timestamp': '2023-08-23T23:56:16.545000Z'},
#                           {'empty_slots': 4,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834894,
#                                      'normal_bikes': 12,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 16,
#                                      'uid': '0004'},
#                            'free_bikes': 12,
#                            'id': '32603a87cfca71d0f7dfa3513bad69d5',
#                            'latitude': 49.274566,
#                            'longitude': -123.121817,
#                            'name': 'Yaletown-Roundhouse Station',
#                            'timestamp': '2023-08-23T23:56:16.507000Z'},
#                           {'empty_slots': 16,
#                            'extra': {'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834602,
#                                      'normal_bikes': 6,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 26,
#                                      'uid': '0005'},
#                            'free_bikes': 10,
#                            'id': '6d42fa40360f9a6b2bf641c7b8bb2862',
#                            'latitude': 49.279764,
#                            'longitude': -123.110154,
#                            'name': 'Dunsmuir & Beatty',
#                            'timestamp': '2023-08-23T23:56:16.510000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834648,
#                                      'normal_bikes': 0,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 16,
#                                      'uid': '0007'},
#                            'free_bikes': 4,
#                            'id': '66f873d641d448bd1572ab086665a458',
#                            'latitude': 49.260599,
#                            'longitude': -123.113504,
#                            'name': '12th & Yukon (City Hall)',
#                            'timestamp': '2023-08-23T23:56:16.525000Z'},
#                           {'empty_slots': 14,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834906,
#                                      'normal_bikes': 2,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 16,
#                                      'uid': '0008'},
#                            'free_bikes': 2,
#                            'id': '485d4d24c803cfde829ab89699fed833',
#                            'latitude': 49.264215,
#                            'longitude': -123.117772,
#                            'name': '8th & Ash',
#                            'timestamp': '2023-08-23T23:56:16.552000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834785,
#                                      'normal_bikes': 6,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0009'},
#                            'free_bikes': 6,
#                            'id': 'b07d513f87897cff7319a0e59d7e567c',
#                            'latitude': 49.270877,
#                            'longitude': -123.115103,
#                            'name': 'Spyglass & Seawall',
#                            'timestamp': '2023-08-23T23:56:16.553000Z'},
#                           {'empty_slots': 11,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834733,
#                                      'normal_bikes': 2,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0010'},
#                            'free_bikes': 3,
#                            'id': 'd1c9556d92f329703229fb3e33899a3b',
#                            'latitude': 49.26893,
#                            'longitude': -123.11813,
#                            'name': 'Stamps Landing',
#                            'timestamp': '2023-08-23T23:56:16.597000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834894,
#                                      'normal_bikes': 11,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0011'},
#                            'free_bikes': 11,
#                            'id': '95e624191c655f50e401d280cd39a9ad',
#                            'latitude': 49.271721,
#                            'longitude': -123.104207,
#                            'name': 'Ontario & Seawall',
#                            'timestamp': '2023-08-23T23:56:16.595000Z'},
#                           {'empty_slots': 13,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834881,
#                                      'normal_bikes': 11,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 26,
#                                      'uid': '0014'},
#                            'free_bikes': 13,
#                            'id': '3e112f9fe877e0003780386359060ae6',
#                            'latitude': 49.287214,
#                            'longitude': -123.11287,
#                            'name': 'Canada Place',
#                            'timestamp': '2023-08-23T23:56:16.593000Z'},
#                           {'empty_slots': 10,
#                            'extra': {'ebikes': 5,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834803,
#                                      'normal_bikes': 5,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0015'},
#                            'free_bikes': 10,
#                            'id': '6993b3dbb0758927967592ea612a2b1e',
#                            'latitude': 49.282409,
#                            'longitude': -123.118541,
#                            'name': 'Granville & Georgia',
#                            'timestamp': '2023-08-23T23:56:16.591000Z'},
#                           {'empty_slots': 2,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834908,
#                                      'normal_bikes': 21,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 26,
#                                      'uid': '0016'},
#                            'free_bikes': 23,
#                            'id': 'bf8408067b0e0c963f3ff526977bcef3',
#                            'latitude': 49.287097,
#                            'longitude': -123.118551,
#                            'name': 'Pender & Burrard',
#                            'timestamp': '2023-08-23T23:56:16.590000Z'},
#                           {'empty_slots': 15,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834702,
#                                      'normal_bikes': 5,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 22,
#                                      'uid': '0017'},
#                            'free_bikes': 6,
#                            'id': 'd2244f1a81d317c76cabd65e81250835',
#                            'latitude': 49.273471,
#                            'longitude': -123.118016,
#                            'name': 'Marinaside & Davie',
#                            'timestamp': '2023-08-23T23:56:16.585000Z'},
#                           {'empty_slots': 4,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834843,
#                                      'normal_bikes': 20,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '0019'},
#                            'free_bikes': 22,
#                            'id': '0b543fc4e694fe07a54dac48bb1b3390',
#                            'latitude': 49.282758,
#                            'longitude': -123.122092,
#                            'name': 'Robson & Hornby',
#                            'timestamp': '2023-08-23T23:56:16.608000Z'},
#                           {'empty_slots': 6,
#                            'extra': {'ebikes': 5,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834677,
#                                      'normal_bikes': 11,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 22,
#                                      'uid': '0024'},
#                            'free_bikes': 16,
#                            'id': 'fbb1d30d7f30b049873f5be5688563d4',
#                            'latitude': 49.28602,
#                            'longitude': -123.116624,
#                            'name': 'Hornby & Pender',
#                            'timestamp': '2023-08-23T23:56:16.666000Z'},
#                           {'empty_slots': 16,
#                            'extra': {'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834499,
#                                      'normal_bikes': 1,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0025'},
#                            'free_bikes': 4,
#                            'id': '7181df50ee1d1a05559399211382b7c8',
#                            'latitude': 49.279739,
#                            'longitude': -123.116251,
#                            'name': 'Homer & Robson (Vancouver Public Library)',
#                            'timestamp': '2023-08-23T23:56:16.667000Z'},
#                           {'empty_slots': 13,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834825,
#                                      'normal_bikes': 6,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0026'},
#                            'free_bikes': 7,
#                            'id': '2ef000bc9d4650d8cc6198c4d570b19f',
#                            'latitude': 49.277483,
#                            'longitude': -123.114279,
#                            'name': 'Beatty & Robson',
#                            'timestamp': '2023-08-23T23:56:16.660000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834622,
#                                      'normal_bikes': 5,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0027'},
#                            'free_bikes': 6,
#                            'id': 'b7683a86874e6300fd89f4cc0b075f57',
#                            'latitude': 49.275679,
#                            'longitude': -123.116963,
#                            'name': 'Beatty & Nelson',
#                            'timestamp': '2023-08-23T23:56:16.661000Z'},
#                           {'empty_slots': 6,
#                            'extra': {'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834778,
#                                      'normal_bikes': 12,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 22,
#                                      'uid': '0030'},
#                            'free_bikes': 15,
#                            'id': '3367c1e1dbf73caf7c10e4c96a92f58d',
#                            'latitude': 49.282759,
#                            'longitude': -123.106955,
#                            'name': 'Abbott & Cordova',
#                            'timestamp': '2023-08-23T23:56:16.319000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834676,
#                                      'normal_bikes': 6,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0032'},
#                            'free_bikes': 6,
#                            'id': '1d7e73b3321ebb6713774d376247d9f9',
#                            'latitude': 49.288444,
#                            'longitude': -123.139203,
#                            'name': 'Comox & Denman',
#                            'timestamp': '2023-08-23T23:56:16.322000Z'},
#                           {'empty_slots': 6,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834904,
#                                      'normal_bikes': 8,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0034'},
#                            'free_bikes': 8,
#                            'id': '664502c28e8147615f17b8ea355f40d0',
#                            'latitude': 49.289124,
#                            'longitude': -123.12196,
#                            'name': 'Cordova & Bute',
#                            'timestamp': '2023-08-23T23:56:16.313000Z'},
#                           {'empty_slots': 18,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834532,
#                                      'normal_bikes': 0,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0037'},
#                            'free_bikes': 0,
#                            'id': '6c24a62b5ee0a2a8014eb0dfb6d40025',
#                            'latitude': 49.28062,
#                            'longitude': -123.12482,
#                            'name': 'Hornby & Nelson',
#                            'timestamp': '2023-08-23T23:56:16.314000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834641,
#                                      'normal_bikes': 2,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 15,
#                                      'uid': '0039'},
#                            'free_bikes': 2,
#                            'id': 'fad9ebcf614dd1a72593a34072ff76f8',
#                            'latitude': 49.279938,
#                            'longitude': -123.127478,
#                            'name': 'Helmcken & Burrard',
#                            'timestamp': '2023-08-23T23:56:16.305000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834574,
#                                      'normal_bikes': 2,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0044'},
#                            'free_bikes': 3,
#                            'id': '3a4131fa94946d93d3529136efd62413',
#                            'latitude': 49.273663,
#                            'longitude': -123.127075,
#                            'name': 'Pacific & Richards',
#                            'timestamp': '2023-08-23T23:56:16.345000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834479,
#                                      'normal_bikes': 4,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0047'},
#                            'free_bikes': 6,
#                            'id': '25318ec3e06fae1397a3a2f645104149',
#                            'latitude': 49.28972,
#                            'longitude': -123.144028,
#                            'name': 'Chilco & Beach',
#                            'timestamp': '2023-08-23T23:56:16.348000Z'},
#                           {'empty_slots': 6,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834843,
#                                      'normal_bikes': 3,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 12,
#                                      'uid': '0048'},
#                            'free_bikes': 4,
#                            'id': '444991edc9550be0908f032da5e3c95f',
#                            'latitude': 49.285253,
#                            'longitude': -123.134356,
#                            'name': 'Comox & Broughton',
#                            'timestamp': '2023-08-23T23:56:16.338000Z'},
#                           {'empty_slots': 18,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834905,
#                                      'normal_bikes': 0,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 22,
#                                      'uid': '0050'},
#                            'free_bikes': 2,
#                            'id': '434b6f4e7fc30198f901b60fc905f609',
#                            'latitude': 49.283343,
#                            'longitude': -123.131099,
#                            'name': 'Bute & Comox',
#                            'timestamp': '2023-08-23T23:56:16.365000Z'},
#                           {'empty_slots': 20,
#                            'extra': {'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834774,
#                                      'normal_bikes': 7,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 32,
#                                      'uid': '0052'},
#                            'free_bikes': 11,
#                            'id': 'f97d5bf41f35aa181288429fb52e3488',
#                            'latitude': 49.284605,
#                            'longitude': -123.108662,
#                            'name': 'Cambie & Water',
#                            'timestamp': '2023-08-23T23:56:16.364000Z'},
#                           {'empty_slots': 3,
#                            'extra': {'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834707,
#                                      'normal_bikes': 21,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 28,
#                                      'uid': '0053'},
#                            'free_bikes': 25,
#                            'id': 'fef69fb400210d861107a61db954d037',
#                            'latitude': 49.279821,
#                            'longitude': -123.10802,
#                            'name': 'Keefer & Abbott',
#                            'timestamp': '2023-08-23T23:56:16.363000Z'},
#                           {'empty_slots': 5,
#                            'extra': {'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834828,
#                                      'normal_bikes': 8,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 16,
#                                      'uid': '0054'},
#                            'free_bikes': 11,
#                            'id': '9d3123425823420514b8ad410074f02d',
#                            'latitude': 49.278004,
#                            'longitude': -123.105664,
#                            'name': 'Expo & Carrall',
#                            'timestamp': '2023-08-23T23:56:16.368000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834576,
#                                      'normal_bikes': 6,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0055'},
#                            'free_bikes': 6,
#                            'id': 'f1ca711137cde59e824167a4274df888',
#                            'latitude': 49.279342,
#                            'longitude': -123.101822,
#                            'name': 'Keefer & Columbia',
#                            'timestamp': '2023-08-23T23:56:16.367000Z'},
#                           {'empty_slots': 16,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834630,
#                                      'normal_bikes': 8,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 26,
#                                      'uid': '0057'},
#                            'free_bikes': 9,
#                            'id': '4f6ebf2026d540ffe40e29a80138ad5e',
#                            'latitude': 49.273833,
#                            'longitude': -123.114373,
#                            'name': 'Marinaside & Cooperage',
#                            'timestamp': '2023-08-23T23:56:16.366000Z'},
#                           {'empty_slots': 18,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834698,
#                                      'normal_bikes': 8,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 26,
#                                      'uid': '0060'},
#                            'free_bikes': 8,
#                            'id': 'be14efdc86dedd6a8cd338e78ab4e7c7',
#                            'latitude': 49.28526,
#                            'longitude': -123.141809,
#                            'name': 'Bidwell & Burnaby',
#                            'timestamp': '2023-08-23T23:56:16.502000Z'},
#                           {'empty_slots': 21,
#                            'extra': {'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834827,
#                                      'normal_bikes': 5,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '0063'},
#                            'free_bikes': 8,
#                            'id': '6ddeafa873279951630a00191333c45d',
#                            'latitude': 49.281506,
#                            'longitude': -123.120101,
#                            'name': 'Robson & Granville',
#                            'timestamp': '2023-08-23T23:56:16.491000Z'},
#                           {'empty_slots': 0,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834541,
#                                      'normal_bikes': 14,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0064'},
#                            'free_bikes': 14,
#                            'id': 'c7b5bec0b2f4ab9a2d3f9d837725620c',
#                            'latitude': 49.276115,
#                            'longitude': -123.114496,
#                            'name': 'Expo & Smithe',
#                            'timestamp': '2023-08-23T23:56:16.488000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834763,
#                                      'normal_bikes': 8,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 22,
#                                      'uid': '0065'},
#                            'free_bikes': 9,
#                            'id': 'b9fd847d53fe45658fee4c46e7f562b8',
#                            'latitude': 49.272827,
#                            'longitude': -123.147744,
#                            'name': 'Cypress & Cornwall',
#                            'timestamp': '2023-08-23T23:56:16.490000Z'},
#                           {'empty_slots': 6,
#                            'extra': {'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834569,
#                                      'normal_bikes': 19,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 28,
#                                      'uid': '0066'},
#                            'free_bikes': 22,
#                            'id': 'c2be5403b1c101e8032cf6696457200e',
#                            'latitude': 49.269361,
#                            'longitude': -123.13782,
#                            'name': 'Anderson & 2nd',
#                            'timestamp': '2023-08-23T23:56:16.486000Z'},
#                           {'empty_slots': 6,
#                            'extra': {'ebikes': 5,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834841,
#                                      'normal_bikes': 3,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0069'},
#                            'free_bikes': 8,
#                            'id': '71c064fa93cab5f0b7306e6c923b77c4',
#                            'latitude': 49.2653,
#                            'longitude': -123.13811,
#                            'name': '7th & Granville',
#                            'timestamp': '2023-08-23T23:56:16.506000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834327,
#                                      'normal_bikes': 0,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0070'},
#                            'free_bikes': 2,
#                            'id': '96bf713e60bc35cc2feb5fd53a4f3471',
#                            'latitude': 49.262598,
#                            'longitude': -123.138921,
#                            'name': '10th & Granville',
#                            'timestamp': '2023-08-23T23:56:16.567000Z'},
#                           {'empty_slots': 11,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834825,
#                                      'normal_bikes': 1,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0071'},
#                            'free_bikes': 2,
#                            'id': '8dc684732a2a25bdf63ec0ecccee4e6e',
#                            'latitude': 49.25894,
#                            'longitude': -123.139272,
#                            'name': '14th & Granville',
#                            'timestamp': '2023-08-23T23:56:16.566000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834541,
#                                      'normal_bikes': 1,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0072'},
#                            'free_bikes': 3,
#                            'id': '686c0fdb962e26e274d81fc286c010dd',
#                            'latitude': 49.258763,
#                            'longitude': -123.115392,
#                            'name': '14th & Cambie',
#                            'timestamp': '2023-08-23T23:56:16.570000Z'},
#                           {'empty_slots': 6,
#                            'extra': {'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834806,
#                                      'normal_bikes': 10,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0073'},
#                            'free_bikes': 14,
#                            'id': '0cf6cd1809fa7f510812f5b052f578c4',
#                            'latitude': 49.266724,
#                            'longitude': -123.104824,
#                            'name': 'Ontario & 5th',
#                            'timestamp': '2023-08-23T23:56:16.568000Z'},
#                           {'empty_slots': 11,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834824,
#                                      'normal_bikes': 5,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0074'},
#                            'free_bikes': 7,
#                            'id': '93c88a18c673e2c72a6afa93d6b89f18',
#                            'latitude': 49.262141,
#                            'longitude': -123.101961,
#                            'name': '10th & Main',
#                            'timestamp': '2023-08-23T23:56:16.573000Z'},
#                           {'empty_slots': 7,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834829,
#                                      'normal_bikes': 10,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0076'},
#                            'free_bikes': 10,
#                            'id': '8fb5ce1e34ad31de940481953aea452c',
#                            'latitude': 49.268269,
#                            'longitude': -123.147885,
#                            'name': 'Cypress & 4th',
#                            'timestamp': '2023-08-23T23:56:16.580000Z'},
#                           {'empty_slots': 19,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834821,
#                                      'normal_bikes': 8,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 28,
#                                      'uid': '0077'},
#                            'free_bikes': 8,
#                            'id': 'aa704bfba40286bd0661b64d1f75e778',
#                            'latitude': 49.275717,
#                            'longitude': -123.142564,
#                            'name': 'Vanier Park',
#                            'timestamp': '2023-08-23T23:56:16.576000Z'},
#                           {'empty_slots': 2,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834856,
#                                      'normal_bikes': 16,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0078'},
#                            'free_bikes': 18,
#                            'id': '8c9ea7f2132376859ef34fab981d6932',
#                            'latitude': 49.276436,
#                            'longitude': -123.11877,
#                            'name': 'Nelson & Mainland',
#                            'timestamp': '2023-08-23T23:56:16.583000Z'},
#                           {'empty_slots': 16,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834844,
#                                      'normal_bikes': 0,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0079'},
#                            'free_bikes': 2,
#                            'id': '1d4153659a0a0a2089078c739df6737d',
#                            'latitude': 49.277844,
#                            'longitude': -123.120942,
#                            'name': 'Nelson & Richards',
#                            'timestamp': '2023-08-23T23:56:16.582000Z'},
#                           {'empty_slots': 14,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834907,
#                                      'normal_bikes': 2,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0081'},
#                            'free_bikes': 4,
#                            'id': 'fbb4c06b719596c21f91fd51ef6d4710',
#                            'latitude': 49.265089,
#                            'longitude': -123.119425,
#                            'name': '7th & Heather',
#                            'timestamp': '2023-08-23T23:56:16.653000Z'},
#                           {'empty_slots': 18,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834665,
#                                      'normal_bikes': 1,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0088'},
#                            'free_bikes': 2,
#                            'id': '72c1049dfbbde7c24ec45c14f1a5ee85',
#                            'latitude': 49.28026,
#                            'longitude': -123.135244,
#                            'name': 'Harwood & Bute',
#                            'timestamp': '2023-08-23T23:56:16.635000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834604,
#                                      'normal_bikes': 10,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0092'},
#                            'free_bikes': 10,
#                            'id': '00fa94ad698dc4a9e4d708d6fd32f294',
#                            'latitude': 49.291909,
#                            'longitude': -123.140713,
#                            'name': 'Chilco & Barclay',
#                            'timestamp': '2023-08-23T23:56:16.724000Z'},
#                           {'empty_slots': 11,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834907,
#                                      'normal_bikes': 4,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 16,
#                                      'uid': '0093'},
#                            'free_bikes': 5,
#                            'id': 'efa947b901a2cf85b58320b3ad26a2fe',
#                            'latitude': 49.293257,
#                            'longitude': -123.138563,
#                            'name': 'Chilco & Robson',
#                            'timestamp': '2023-08-23T23:56:16.722000Z'},
#                           {'empty_slots': 2,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834906,
#                                      'normal_bikes': 13,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0096'},
#                            'free_bikes': 14,
#                            'id': '66a53e9c32e4f5c724f9478240020142',
#                            'latitude': 49.288011,
#                            'longitude': -123.132006,
#                            'name': 'Nicola & Robson',
#                            'timestamp': '2023-08-23T23:56:16.719000Z'},
#                           {'empty_slots': 5,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834625,
#                                      'normal_bikes': 12,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0098'},
#                            'free_bikes': 12,
#                            'id': '97b25faf822b93fdbf72da1d594c0288',
#                            'latitude': 49.28117,
#                            'longitude': -123.104419,
#                            'name': 'Carrall & Hastings',
#                            'timestamp': '2023-08-23T23:56:16.711000Z'},
#                           {'empty_slots': 21,
#                            'extra': {'ebikes': 5,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834763,
#                                      'normal_bikes': 2,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 28,
#                                      'uid': '0099'},
#                            'free_bikes': 7,
#                            'id': '6c7fb9043e6df5a4cc50404581a947b9',
#                            'latitude': 49.283227,
#                            'longitude': -123.120523,
#                            'name': "šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver "
#                                    'Art Gallery',
#                            'timestamp': '2023-08-23T23:56:16.709000Z'},
#                           {'empty_slots': 16,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834832,
#                                      'normal_bikes': 0,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 16,
#                                      'uid': '0101'},
#                            'free_bikes': 0,
#                            'id': '30bf49544b1c864688b78172d42cca5e',
#                            'latitude': 49.299292,
#                            'longitude': -123.130281,
#                            'name': 'Stanley Park - Vancouver Aquarium',
#                            'timestamp': '2023-08-23T23:56:16.406000Z'},
#                           {'empty_slots': 3,
#                            'extra': {'ebikes': 5,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834695,
#                                      'normal_bikes': 8,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 16,
#                                      'uid': '0102'},
#                            'free_bikes': 13,
#                            'id': '9f63cebac9073eac3e90be2b9a91b02b',
#                            'latitude': 49.29534,
#                            'longitude': -123.150433,
#                            'name': 'Stanley Park - Second Beach North',
#                            'timestamp': '2023-08-23T23:56:16.410000Z'},
#                           {'empty_slots': 6,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834903,
#                                      'normal_bikes': 11,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 19,
#                                      'uid': '0104'},
#                            'free_bikes': 13,
#                            'id': '9aa325529164ec68b4d96c4f1c4fc7c1',
#                            'latitude': 49.294318,
#                            'longitude': -123.148808,
#                            'name': 'Stanley Park - Second Beach South',
#                            'timestamp': '2023-08-23T23:56:16.403000Z'},
#                           {'empty_slots': 15,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834868,
#                                      'normal_bikes': 3,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0105'},
#                            'free_bikes': 3,
#                            'id': 'e3d32ad772a5898c3b96c4d23d2cd542',
#                            'latitude': 49.298657,
#                            'longitude': -123.121176,
#                            'name': 'Stanley Park - Totem Poles',
# ...
#                            'latitude': 49.246243,
#                            'longitude': -123.124373,
#                            'name': '28th & Willow',
#                            'timestamp': '2023-08-23T23:56:16.334000Z'},
#                           {'empty_slots': 11,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834513,
#                                      'normal_bikes': 1,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 12,
#                                      'uid': '0554'},
#                            'free_bikes': 1,
#                            'id': '97388f4e4ea102a30345524bda465f4e',
#                            'latitude': 49.249722,
#                            'longitude': -123.104991,
#                            'name': 'Ontario & 23rd',
#                            'timestamp': '2023-08-23T23:56:16.726000Z'},
#                           {'empty_slots': 14,
#                            'extra': {'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834872,
#                                      'normal_bikes': 3,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 22,
#                                      'uid': '0557'},
#                            'free_bikes': 7,
#                            'id': '066ecc3584913fa035ec1417323beb80',
#                            'latitude': 49.243375,
#                            'longitude': -123.104978,
#                            'name': '30th & Ontario',
#                            'timestamp': '2023-08-23T23:56:16.615000Z'},
#                           {'empty_slots': 11,
#                            'extra': {'ebikes': 6,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834763,
#                                      'normal_bikes': 3,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0642'},
#                            'free_bikes': 9,
#                            'id': 'b530d04d393d71cffb8b8b07f4a82380',
#                            'latitude': 49.282087,
#                            'longitude': -123.056909,
#                            'name': 'Franklin & Nanaimo',
#                            'timestamp': '2023-08-23T23:56:16.564000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834887,
#                                      'normal_bikes': 2,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 16,
#                                      'uid': '0631'},
#                            'free_bikes': 4,
#                            'id': '06bdc4d55f34b2a491305534fd5defda',
#                            'latitude': 49.283968,
#                            'longitude': -123.061615,
#                            'name': 'Lakewood & Triumph',
#                            'timestamp': '2023-08-23T23:56:16.503000Z'},
#                           {'empty_slots': 9,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834834,
#                                      'normal_bikes': 9,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0611'},
#                            'free_bikes': 9,
#                            'id': '8e44a17d2fa446ca220b90c7063b42ca',
#                            'latitude': 49.287464,
#                            'longitude': -123.060771,
#                            'name': 'Wall & Eton',
#                            'timestamp': '2023-08-23T23:56:16.353000Z'},
#                           {'empty_slots': 6,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834807,
#                                      'normal_bikes': 11,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0621'},
#                            'free_bikes': 12,
#                            'id': '7c17f51469f1a7145455f65ef6afbd87',
#                            'latitude': 49.285575,
#                            'longitude': -123.061575,
#                            'name': 'Lakewood & Oxford',
#                            'timestamp': '2023-08-23T23:56:16.470000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834497,
#                                      'normal_bikes': 2,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0532'},
#                            'free_bikes': 2,
#                            'id': 'e1432b72df561a1df34290679ec9c773',
#                            'latitude': 49.251358,
#                            'longitude': -123.115637,
#                            'name': '22nd & Cambie',
#                            'timestamp': '2023-08-23T23:56:16.351000Z'},
#                           {'empty_slots': 13,
#                            'extra': {'ebikes': 5,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834906,
#                                      'normal_bikes': 0,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0524'},
#                            'free_bikes': 5,
#                            'id': '549f00f6039e8bb702a00dcca08a8ed0',
#                            'latitude': 49.249184,
#                            'longitude': -123.116141,
#                            'name': 'King Edward & Cambie',
#                            'timestamp': '2023-08-23T23:56:16.374000Z'},
#                           {'empty_slots': 19,
#                            'extra': {'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834824,
#                                      'normal_bikes': 0,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 22,
#                                      'uid': '0516'},
#                            'free_bikes': 3,
#                            'id': 'd8c4fe5e09b6f010fbaa85cc7302d66b',
#                            'latitude': 49.245535,
#                            'longitude': -123.120496,
#                            'name': 'Heather & 29th',
#                            'timestamp': '2023-08-23T23:56:16.424000Z'},
#                           {'empty_slots': 21,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834849,
#                                      'normal_bikes': 4,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 26,
#                                      'uid': '0041'},
#                            'free_bikes': 5,
#                            'id': '0c42f45e4a14957ad4a6d521d0ba8bc3',
#                            'latitude': 49.289255,
#                            'longitude': -123.132677,
#                            'name': 'Cardero & Robson',
#                            'timestamp': '2023-08-23T23:56:16.344000Z'},
#                           {'empty_slots': 15,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834734,
#                                      'normal_bikes': 5,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0352'},
#                            'free_bikes': 5,
#                            'id': '62a202eb98c0a4b09ba6746f5ee94ab3',
#                            'latitude': 49.252656,
#                            'longitude': -123.067965,
#                            'name': 'Commercial & 20th',
#                            'timestamp': '2023-08-23T23:56:16.421000Z'},
#                           {'empty_slots': 13,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834393,
#                                      'normal_bikes': 4,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0210'},
#                            'free_bikes': 5,
#                            'id': '04f64fde5ba1ebde8ad78c74914adb34',
#                            'latitude': 49.259469,
#                            'longitude': -123.145718,
#                            'name': 'Burrard & 14th',
#                            'timestamp': '2023-08-23T23:56:16.437000Z'},
#                           {'empty_slots': 18,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834624,
#                                      'normal_bikes': 2,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '0196'},
#                            'free_bikes': 3,
#                            'id': 'cc2084e365f6f230fe26bae0b6867775',
#                            'latitude': 49.277178,
#                            'longitude': -123.13,
#                            'name': 'Hornby & Drake',
#                            'timestamp': '2023-08-23T23:56:16.461000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834909,
#                                      'normal_bikes': 10,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0200'},
#                            'free_bikes': 11,
#                            'id': 'f38bac9712f3beee2149ba2a97048878',
#                            'latitude': 49.291597,
#                            'longitude': -123.129158,
#                            'name': 'Cardero & Bayshore',
#                            'timestamp': '2023-08-23T23:56:16.386000Z'},
#                           {'empty_slots': 18,
#                            'extra': {'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834698,
#                                      'normal_bikes': 1,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 22,
#                                      'uid': '0565'},
#                            'free_bikes': 4,
#                            'id': '9ee3bc9e836768e3e04e4f3328dae03b',
#                            'latitude': 49.247204,
#                            'longitude': -123.101549,
#                            'name': '27th & Main',
#                            'timestamp': '2023-08-23T23:56:16.648000Z'},
#                           {'empty_slots': 3,
#                            'extra': {'ebikes': 12,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834909,
#                                      'normal_bikes': 3,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '0021'},
#                            'free_bikes': 15,
#                            'id': 'aa1cbf97abc3cd50515bc54633a9bb2a',
#                            'latitude': 49.2856698,
#                            'longitude': -123.1125432,
#                            'name': 'Cordova & Granville',
#                            'timestamp': '2023-08-23T23:56:16.657000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834843,
#                                      'normal_bikes': 2,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 14,
#                                      'uid': '0563'},
#                            'free_bikes': 2,
#                            'id': '13021bba7bbeca1ccd8726ca17da59e6',
#                            'latitude': 49.25094,
#                            'longitude': -123.101306,
#                            'name': '22nd & Main',
#                            'timestamp': '2023-08-23T23:56:16.652000Z'},
#                           {'empty_slots': 25,
#                            'extra': {'ebikes': 5,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834377,
#                                      'normal_bikes': 10,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 40,
#                                      'uid': '1002'},
#                            'free_bikes': 15,
#                            'id': 'a74744ce4bb7ea2aa9f406ac8bff95d8',
#                            'latitude': 49.280977,
#                            'longitude': -123.035969,
#                            'name': 'PNE - Hastings & Windermere',
#                            'timestamp': '2023-08-23T23:56:16.369000Z'},
#                           {'empty_slots': 12,
#                            'extra': {'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1692834887,
#                                      'normal_bikes': 8,
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 20,
#                                      'uid': '0315'},
#                            'free_bikes': 8,
#                            'id': '5699b40126e10c2f68eefc3eb18ff3a1',
#                            'latitude': 49.270783,
#                            'longitude': -123.141564,
#                            'name': '1st & Fir',
#                            'timestamp': '2023-08-23T23:56:16.354000Z'}]}}

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
stations = cb_data['network']['stations']
keys = ['latitude', 'longitude', 'free_bikes']
cb_values = []
for station in stations:
    cb_values += [(key, station[key]) for key in keys]

pprint(cb_values)
# Out:
# [('latitude', 49.262487),
#  ('longitude', -123.114397),
#  ('free_bikes', 17),
#  ('latitude', 49.274566),
#  ('longitude', -123.121817),
#  ('free_bikes', 12),
#  ('latitude', 49.279764),
#  ('longitude', -123.110154),
#  ('free_bikes', 10),
#  ('latitude', 49.260599),
#  ('longitude', -123.113504),
#  ('free_bikes', 4),
#  ('latitude', 49.264215),
#  ('longitude', -123.117772),
#  ('free_bikes', 2),
#  ('latitude', 49.270877),
#  ('longitude', -123.115103),
#  ('free_bikes', 6),
#  ('latitude', 49.26893),
#  ('longitude', -123.11813),
#  ('free_bikes', 3),
#  ('latitude', 49.271721),
#  ('longitude', -123.104207),
#  ('free_bikes', 11),
#  ('latitude', 49.287214),
#  ('longitude', -123.11287),
#  ('free_bikes', 13),
#  ('latitude', 49.282409),
#  ('longitude', -123.118541),
#  ('free_bikes', 10),
#  ('latitude', 49.287097),
#  ('longitude', -123.118551),
#  ('free_bikes', 23),
#  ('latitude', 49.273471),
#  ('longitude', -123.118016),
#  ('free_bikes', 6),
#  ('latitude', 49.282758),
#  ('longitude', -123.122092),
#  ('free_bikes', 22),
#  ('latitude', 49.28602),
#  ('longitude', -123.116624),
#  ('free_bikes', 16),
#  ('latitude', 49.279739),
#  ('longitude', -123.116251),
#  ('free_bikes', 4),
#  ('latitude', 49.277483),
#  ('longitude', -123.114279),
#  ('free_bikes', 7),
#  ('latitude', 49.275679),
#  ('longitude', -123.116963),
#  ('free_bikes', 6),
#  ('latitude', 49.282759),
#  ('longitude', -123.106955),
#  ('free_bikes', 15),
#  ('latitude', 49.288444),
#  ('longitude', -123.139203),
#  ('free_bikes', 6),
#  ('latitude', 49.289124),
#  ('longitude', -123.12196),
#  ('free_bikes', 8),
#  ('latitude', 49.28062),
#  ('longitude', -123.12482),
#  ('free_bikes', 0),
#  ('latitude', 49.279938),
#  ('longitude', -123.127478),
#  ('free_bikes', 2),
#  ('latitude', 49.273663),
#  ('longitude', -123.127075),
#  ('free_bikes', 3),
#  ('latitude', 49.28972),
#  ('longitude', -123.144028),
#  ('free_bikes', 6),
#  ('latitude', 49.285253),
#  ('longitude', -123.134356),
#  ('free_bikes', 4),
#  ('latitude', 49.283343),
#  ('longitude', -123.131099),
#  ('free_bikes', 2),
#  ('latitude', 49.284605),
#  ('longitude', -123.108662),
#  ('free_bikes', 11),
#  ('latitude', 49.279821),
#  ('longitude', -123.10802),
#  ('free_bikes', 25),
#  ('latitude', 49.278004),
#  ('longitude', -123.105664),
#  ('free_bikes', 11),
#  ('latitude', 49.279342),
#  ('longitude', -123.101822),
#  ('free_bikes', 6),
#  ('latitude', 49.273833),
#  ('longitude', -123.114373),
#  ('free_bikes', 9),
#  ('latitude', 49.28526),
#  ('longitude', -123.141809),
#  ('free_bikes', 8),
#  ('latitude', 49.281506),
#  ('longitude', -123.120101),
#  ('free_bikes', 8),
#  ('latitude', 49.276115),
#  ('longitude', -123.114496),
#  ('free_bikes', 14),
#  ('latitude', 49.272827),
#  ('longitude', -123.147744),
#  ('free_bikes', 9),
#  ('latitude', 49.269361),
#  ('longitude', -123.13782),
#  ('free_bikes', 22),
#  ('latitude', 49.2653),
#  ('longitude', -123.13811),
#  ('free_bikes', 8),
#  ('latitude', 49.262598),
#  ('longitude', -123.138921),
#  ('free_bikes', 2),
#  ('latitude', 49.25894),
#  ('longitude', -123.139272),
#  ('free_bikes', 2),
#  ('latitude', 49.258763),
#  ('longitude', -123.115392),
#  ('free_bikes', 3),
#  ('latitude', 49.266724),
#  ('longitude', -123.104824),
#  ('free_bikes', 14),
#  ('latitude', 49.262141),
#  ('longitude', -123.101961),
#  ('free_bikes', 7),
#  ('latitude', 49.268269),
#  ('longitude', -123.147885),
#  ('free_bikes', 10),
#  ('latitude', 49.275717),
#  ('longitude', -123.142564),
#  ('free_bikes', 8),
#  ('latitude', 49.276436),
#  ('longitude', -123.11877),
#  ('free_bikes', 18),
#  ('latitude', 49.277844),
#  ('longitude', -123.120942),
#  ('free_bikes', 2),
#  ('latitude', 49.265089),
#  ('longitude', -123.119425),
#  ('free_bikes', 4),
#  ('latitude', 49.28026),
#  ('longitude', -123.135244),
#  ('free_bikes', 2),
#  ('latitude', 49.291909),
#  ('longitude', -123.140713),
#  ('free_bikes', 10),
#  ('latitude', 49.293257),
#  ('longitude', -123.138563),
#  ('free_bikes', 5),
#  ('latitude', 49.288011),
#  ('longitude', -123.132006),
#  ('free_bikes', 14),
#  ('latitude', 49.28117),
#  ('longitude', -123.104419),
#  ('free_bikes', 12),
#  ('latitude', 49.283227),
#  ('longitude', -123.120523),
#  ('free_bikes', 7),
#  ('latitude', 49.299292),
#  ('longitude', -123.130281),
#  ('free_bikes', 0),
#  ('latitude', 49.29534),
#  ('longitude', -123.150433),
#  ('free_bikes', 13),
#  ('latitude', 49.294318),
#  ('longitude', -123.148808),
#  ('free_bikes', 13),
#  ('latitude', 49.298657),
#  ('longitude', -123.121176),
#  ('free_bikes', 3),
#  ('latitude', 49.259183),
#  ('longitude', -123.120126),
#  ('free_bikes', 6),
#  ('latitude', 49.263837),
#  ('longitude', -123.105173),
#  ('free_bikes', 9),
#  ('latitude', 49.270721),
#  ('longitude', -123.146175),
#  ('free_bikes', 17),
#  ('latitude', 49.265605),
#  ('longitude', -123.152566),
#  ('free_bikes', 10),
#  ('latitude', 49.267222),
#  ('longitude', -123.153157),
#  ('free_bikes', 10),
#  ('latitude', 49.262255),
#  ('longitude', -123.126217),
#  ('free_bikes', 5),
#  ('latitude', 49.257654),
#  ('longitude', -123.153212),
#  ('free_bikes', 9),
#  ('latitude', 49.25919),
#  ('longitude', -123.148268),
#  ('free_bikes', 2),
#  ('latitude', 49.25741),
#  ('longitude', -123.148531),
#  ('free_bikes', 2),
#  ('latitude', 49.285953),
#  ('longitude', -123.124066),
#  ('free_bikes', 7),
#  ('latitude', 49.280881),
#  ('longitude', -123.130672),
#  ('free_bikes', 3),
#  ('latitude', 49.256845),
#  ('longitude', -123.120071),
#  ('free_bikes', 1),
#  ('latitude', 49.25849),
#  ('longitude', -123.104799),
#  ('free_bikes', 5),
#  ('latitude', 49.258425),
#  ('longitude', -123.100792),
#  ('free_bikes', 3),
#  ('latitude', 49.270905),
#  ('longitude', -123.126006),
#  ('free_bikes', 14),
#  ('latitude', 49.273568),
#  ('longitude', -123.129935),
#  ('free_bikes', 7),
#  ('latitude', 49.277141),
#  ('longitude', -123.122589),
#  ('free_bikes', 10),
#  ('latitude', 49.267859),
#  ('longitude', -123.145782),
#  ('free_bikes', 12),
#  ('latitude', 49.265336),
#  ('longitude', -123.145823),
#  ('free_bikes', 7),
#  ('latitude', 49.267628),
#  ('longitude', -123.127698),
#  ('free_bikes', 3),
#  ('latitude', 49.275938),
#  ('longitude', -123.145939),
#  ('free_bikes', 7),
#  ('latitude', 49.2756),
#  ('longitude', -123.102661),
#  ('free_bikes', 8),
#  ('latitude', 49.284157),
#  ('longitude', -123.099917),
#  ('free_bikes', 18),
#  ('latitude', 49.258924),
#  ('longitude', -123.152591),
#  ('free_bikes', 10),
#  ('latitude', 49.266774),
#  ('longitude', -123.141135),
#  ('free_bikes', 13),
#  ('latitude', 49.273355),
#  ('longitude', -123.154493),
#  ('free_bikes', 16),
#  ('latitude', 49.276144),
#  ('longitude', -123.151272),
#  ('free_bikes', 3),
#  ('latitude', 49.268339),
#  ('longitude', -123.157443),
#  ('free_bikes', 4),
#  ('latitude', 49.284062),
#  ('longitude', -123.095097),
#  ('free_bikes', 2),
#  ('latitude', 49.261742),
#  ('longitude', -123.13148),
#  ('free_bikes', 1),
#  ('latitude', 49.262206),
#  ('longitude', -123.109091),
#  ('free_bikes', 4),
#  ('latitude', 49.27023),
#  ('longitude', -123.10651),
#  ('free_bikes', 13),
#  ('latitude', 49.262062),
#  ('longitude', -123.104656),
#  ('free_bikes', 8),
#  ('latitude', 49.27033),
#  ('longitude', -123.10275),
#  ('free_bikes', 15),
#  ('latitude', 49.258902),
#  ('longitude', -123.109596),
#  ('free_bikes', 5),
#  ('latitude', 49.282224),
#  ('longitude', -123.132778),
#  ('free_bikes', 2),
#  ('latitude', 49.265071),
#  ('longitude', -123.123864),
#  ('free_bikes', 2),
#  ('latitude', 49.265198),
#  ('longitude', -123.131043),
#  ('free_bikes', 2),
#  ('latitude', 49.273691),
#  ('longitude', -123.102232),
#  ('free_bikes', 1),
#  ('latitude', 49.2685027),
#  ('longitude', -123.0975014),
#  ('free_bikes', 14),
#  ('latitude', 49.278529),
#  ('longitude', -123.100017),
#  ('free_bikes', 2),
#  ('latitude', 49.288682),
#  ('longitude', -123.11818),
#  ('free_bikes', 8),
#  ('latitude', 49.271741),
#  ('longitude', -123.155421),
#  ('free_bikes', 15),
#  ('latitude', 49.262822),
#  ('longitude', -123.14338),
#  ('free_bikes', 9),
#  ('latitude', 49.263635),
#  ('longitude', -123.099236),
#  ('free_bikes', 8),
#  ('latitude', 49.28763),
#  ('longitude', -123.127245),
#  ('free_bikes', 1),
#  ('latitude', 49.297933),
#  ('longitude', -123.130758),
#  ('free_bikes', 13),
#  ('latitude', 49.258819),
#  ('longitude', -123.131317),
#  ('free_bikes', 7),
#  ('latitude', 49.280284),
#  ('longitude', -123.097052),
#  ('free_bikes', 8),
#  ('latitude', 49.276294),
#  ('longitude', -123.106534),
#  ('free_bikes', 2),
#  ('latitude', 49.277469),
#  ('longitude', -123.081315),
#  ('free_bikes', 13),
#  ('latitude', 49.277665),
#  ('longitude', -123.073653),
#  ('free_bikes', 18),
#  ('latitude', 49.277436),
#  ('longitude', -123.070427),
#  ('free_bikes', 11),
#  ('latitude', 49.280332),
#  ('longitude', -123.070068),
#  ('free_bikes', 7),
#  ('latitude', 49.279369),
#  ('longitude', -123.091241),
#  ('free_bikes', 0),
#  ('latitude', 49.283992),
#  ('longitude', -123.091206),
#  ('free_bikes', 9),
#  ('latitude', 49.274881),
#  ('longitude', -123.069323),
#  ('free_bikes', 1),
#  ('latitude', 49.275882),
#  ('longitude', -123.071865),
#  ('free_bikes', 8),
#  ('latitude', 49.273777),
#  ('longitude', -123.092723),
#  ('free_bikes', 9),
#  ('latitude', 49.265005),
#  ('longitude', -123.079481),
#  ('free_bikes', 18),
#  ('latitude', 49.265024),
#  ('longitude', -123.08127),
#  ('free_bikes', 9),
#  ('latitude', 49.271377),
#  ('longitude', -123.069416),
#  ('free_bikes', 6),
#  ('latitude', 49.268616),
#  ('longitude', -123.069908),
#  ('free_bikes', 9),
#  ('latitude', 49.266969),
#  ('longitude', -123.069936),
#  ('free_bikes', 0),
#  ('latitude', 49.263242),
#  ('longitude', -123.070521),
#  ('free_bikes', 8),
#  ('latitude', 49.261403),
#  ('longitude', -123.070102),
#  ('free_bikes', 9),
#  ('latitude', 49.261263),
#  ('longitude', -123.073707),
#  ('free_bikes', 6),
#  ('latitude', 49.262242),
#  ('longitude', -123.081459),
#  ('free_bikes', 4),
#  ('latitude', 49.262321),
#  ('longitude', -123.09306),
#  ('free_bikes', 3),
#  ('latitude', 49.264251),
#  ('longitude', -123.073853),
#  ('free_bikes', 5),
#  ('latitude', 49.266751),
#  ('longitude', -123.073501),
#  ('free_bikes', 3),
#  ('latitude', 49.270684),
#  ('longitude', -123.073562),
#  ('free_bikes', 1),
#  ('latitude', 49.2731),
#  ('longitude', -123.0732),
#  ('free_bikes', 6),
#  ('latitude', 49.254667),
#  ('longitude', -123.101389),
#  ('free_bikes', 7),
#  ('latitude', 49.256694),
#  ('longitude', -123.096579),
#  ('free_bikes', 1),
#  ('latitude', 49.258352),
#  ('longitude', -123.096337),
#  ('free_bikes', 5),
#  ('latitude', 49.258817),
#  ('longitude', -123.092797),
#  ('free_bikes', 6),
#  ('latitude', 49.26151),
#  ('longitude', -123.089413),
#  ('free_bikes', 3),
#  ('latitude', 49.263382),
#  ('longitude', -123.088837),
#  ('free_bikes', 9),
#  ('latitude', 49.261353),
#  ('longitude', -123.085333),
#  ('free_bikes', 3),
#  ('latitude', 49.264466),
#  ('longitude', -123.085183),
#  ('free_bikes', 5),
#  ('latitude', 49.280197),
#  ('longitude', -123.065859),
#  ('free_bikes', 0),
#  ('latitude', 49.266725),
#  ('longitude', -123.065925),
#  ('free_bikes', 4),
#  ('latitude', 49.261188),
#  ('longitude', -123.066009),
#  ('free_bikes', 1),
#  ('latitude', 49.256857),
#  ('longitude', -123.065646),
#  ('free_bikes', 6),
#  ('latitude', 49.283986),
#  ('longitude', -123.065264),
#  ('free_bikes', 13),
#  ('latitude', 49.257985),
#  ('longitude', -123.083366),
#  ('free_bikes', 0),
#  ('latitude', 49.257939),
#  ('longitude', -123.089531),
#  ('free_bikes', 0),
#  ('latitude', 49.256496),
#  ('longitude', -123.075426),
#  ('free_bikes', 3),
#  ('latitude', 49.283236),
#  ('longitude', -123.070443),
#  ('free_bikes', 11),
#  ('latitude', 49.267266),
#  ('longitude', -123.090786),
#  ('free_bikes', 7),
#  ('latitude', 49.265242),
#  ('longitude', -123.095577),
#  ('free_bikes', 8),
#  ('latitude', 49.265213),
#  ('longitude', -123.090785),
#  ('free_bikes', 6),
#  ('latitude', 49.302577),
#  ('longitude', -123.155616),
#  ('free_bikes', 6),
#  ('latitude', 49.277595),
#  ('longitude', -123.09583),
#  ('free_bikes', 10),
#  ('latitude', 49.279235),
#  ('longitude', -123.087528),
#  ('free_bikes', 8),
#  ('latitude', 49.277333),
#  ('longitude', -123.087359),
#  ('free_bikes', 12),
#  ('latitude', 49.273103),
#  ('longitude', -123.069892),
#  ('free_bikes', 0),
#  ('latitude', 49.261973),
#  ('longitude', -123.09725),
#  ('free_bikes', 0),
#  ('latitude', 49.275295),
#  ('longitude', -123.132585),
#  ('free_bikes', 7),
#  ('latitude', 49.285871),
#  ('longitude', -123.12105),
#  ('free_bikes', 6),
#  ('latitude', 49.284893),
#  ('longitude', -123.128685),
#  ('free_bikes', 9),
#  ('latitude', 49.263962),
#  ('longitude', -123.112621),
#  ('free_bikes', 16),
#  ('latitude', 49.277615),
#  ('longitude', -123.091654),
#  ('free_bikes', 8),
#  ('latitude', 49.282214),
#  ('longitude', -123.114101),
#  ('free_bikes', 16),
#  ('latitude', 49.266456),
#  ('longitude', -123.100324),
#  ('free_bikes', 4),
#  ('latitude', 49.268216),
#  ('longitude', -123.103168),
#  ('free_bikes', 16),
#  ('latitude', 49.284554),
#  ('longitude', -123.111031),
#  ('free_bikes', 15),
#  ('latitude', 49.280216),
#  ('longitude', -123.117639),
#  ('free_bikes', 10),
#  ('latitude', 49.266314),
#  ('longitude', -123.116011),
#  ('free_bikes', 10),
#  ('latitude', 49.280852),
#  ('longitude', -123.084746),
#  ('free_bikes', 1),
#  ('latitude', 49.285512),
#  ('longitude', -123.1384),
#  ('free_bikes', 3),
#  ('latitude', 49.27821),
#  ('longitude', -123.136972),
#  ('free_bikes', 12),
#  ('latitude', 49.281301),
#  ('longitude', -123.139108),
#  ('free_bikes', 8),
#  ('latitude', 49.283298),
#  ('longitude', -123.142288),
#  ('free_bikes', 19),
#  ('latitude', 49.280787),
#  ('longitude', -123.115271),
#  ('free_bikes', 2),
#  ('latitude', 49.266476),
#  ('longitude', -123.109389),
#  ('free_bikes', 12),
#  ('latitude', 49.290587),
#  ('longitude', -123.13625),
#  ('free_bikes', 5),
#  ('latitude', 49.262835),
#  ('longitude', -123.152626),
#  ('free_bikes', 7),
#  ('latitude', 49.256825),
#  ('longitude', -123.105234),
#  ('free_bikes', 2),
#  ('latitude', 49.275683),
#  ('longitude', -123.124388),
#  ('free_bikes', 7),
#  ('latitude', 49.263518),
#  ('longitude', -123.09568),
#  ('free_bikes', 0),
#  ('latitude', 49.28691),
#  ('longitude', -123.128818),
#  ('free_bikes', 6),
#  ('latitude', 49.282503),
#  ('longitude', -123.124697),
#  ('free_bikes', 1),
#  ('latitude', 49.283749),
#  ('longitude', -123.136133),
#  ('free_bikes', 2),
#  ('latitude', 49.262944),
#  ('longitude', -123.148109),
#  ('free_bikes', 8),
#  ('latitude', 49.27029),
#  ('longitude', -123.135025),
#  ('free_bikes', 25),
#  ('latitude', 49.280427),
#  ('longitude', -123.074082),
#  ('free_bikes', 15),
#  ('latitude', 49.279259),
#  ('longitude', -123.119145),
#  ('free_bikes', 5),
#  ('latitude', 49.285836),
#  ('longitude', -123.127265),
#  ('free_bikes', 10),
#  ('latitude', 49.272969),
#  ('longitude', -123.164325),
#  ('free_bikes', 5),
#  ('latitude', 49.27247),
#  ('longitude', -123.185643),
#  ('free_bikes', 15),
#  ('latitude', 49.271471),
#  ('longitude', -123.17731),
#  ('free_bikes', 5),
#  ('latitude', 49.290112),
#  ('longitude', -123.127062),
#  ('free_bikes', 4),
#  ('latitude', 49.263523),
#  ('longitude', -123.155267),
#  ('free_bikes', 6),
#  ('latitude', 49.264928),
#  ('longitude', -123.168068),
#  ('free_bikes', 8),
#  ('latitude', 49.264483),
#  ('longitude', -123.173926),
#  ('free_bikes', 17),
#  ('latitude', 49.264579),
#  ('longitude', -123.18373),
#  ('free_bikes', 8),
#  ('latitude', 49.263746),
#  ('longitude', -123.069892),
#  ('free_bikes', 0),
#  ('latitude', 49.258761),
#  ('longitude', -123.127071),
#  ('free_bikes', 8),
#  ('latitude', 49.268974),
#  ('longitude', -123.190701),
#  ('free_bikes', 12),
#  ('latitude', 49.273011),
#  ('longitude', -123.159663),
#  ('free_bikes', 9),
#  ('latitude', 49.266924),
#  ('longitude', -123.173849),
#  ('free_bikes', 15),
#  ('latitude', 49.264326),
#  ('longitude', -123.164725),
#  ('free_bikes', 13),
#  ('latitude', 49.266636),
#  ('longitude', -123.183661),
#  ('free_bikes', 2),
#  ('latitude', 49.254818),
#  ('longitude', -123.114785),
#  ('free_bikes', 5),
#  ('latitude', 49.268837),
#  ('longitude', -123.177633),
#  ('free_bikes', 2),
#  ('latitude', 49.255034),
#  ('longitude', -123.120226),
#  ('free_bikes', 3),
#  ('latitude', 49.271044),
#  ('longitude', -123.170661),
#  ('free_bikes', 10),
#  ('latitude', 49.252691),
#  ('longitude', -123.101289),
#  ('free_bikes', 3),
#  ('latitude', 49.272172),
#  ('longitude', -123.097978),
#  ('free_bikes', 10),
#  ('latitude', 49.271082),
#  ('longitude', -123.191458),
#  ('free_bikes', 0),
#  ('latitude', 49.27808),
#  ('longitude', -123.130557),
#  ('free_bikes', 1),
#  ('latitude', 49.269969),
#  ('longitude', -123.109623),
#  ('free_bikes', 17),
#  ('latitude', 49.287528),
#  ('longitude', -123.142139),
#  ('free_bikes', 22),
#  ('latitude', 49.28803),
#  ('longitude', -123.142135),
#  ('free_bikes', 16),
#  ('latitude', 49.259579),
#  ('longitude', -123.114769),
#  ('free_bikes', 1),
#  ('latitude', 49.2890705989865),
#  ('longitude', -123.138407369468),
#  ('free_bikes', 1),
#  ('latitude', 49.287782),
#  ('longitude', -123.12395),
#  ('free_bikes', 6),
#  ('latitude', 49.28512),
#  ('longitude', -123.11242),
#  ('free_bikes', 16),
#  ('latitude', 49.247854),
#  ('longitude', -123.153422),
#  ('free_bikes', 2),
#  ('latitude', 49.265939),
#  ('longitude', -123.1129),
#  ('free_bikes', 7),
#  ('latitude', 49.261122),
#  ('longitude', -123.097571),
#  ('free_bikes', 0),
#  ('latitude', 49.267725),
#  ('longitude', -123.11311),
#  ('free_bikes', 5),
#  ('latitude', 49.245135),
#  ('longitude', -123.116098),
#  ('free_bikes', 4),
#  ('latitude', 49.274232),
#  ('longitude', -123.129998),
#  ('free_bikes', 11),
#  ('latitude', 49.238105),
#  ('longitude', -123.154966),
#  ('free_bikes', 9),
#  ('latitude', 49.246243),
#  ('longitude', -123.124373),
#  ('free_bikes', 8),
#  ('latitude', 49.249722),
#  ('longitude', -123.104991),
#  ('free_bikes', 1),
#  ('latitude', 49.243375),
#  ('longitude', -123.104978),
#  ('free_bikes', 7),
#  ('latitude', 49.282087),
#  ('longitude', -123.056909),
#  ('free_bikes', 9),
#  ('latitude', 49.283968),
#  ('longitude', -123.061615),
#  ('free_bikes', 4),
#  ('latitude', 49.287464),
#  ('longitude', -123.060771),
#  ('free_bikes', 9),
#  ('latitude', 49.285575),
#  ('longitude', -123.061575),
#  ('free_bikes', 12),
#  ('latitude', 49.251358),
#  ('longitude', -123.115637),
#  ('free_bikes', 2),
#  ('latitude', 49.249184),
#  ('longitude', -123.116141),
#  ('free_bikes', 5),
#  ('latitude', 49.245535),
#  ('longitude', -123.120496),
#  ('free_bikes', 3),
#  ('latitude', 49.289255),
#  ('longitude', -123.132677),
#  ('free_bikes', 5),
#  ('latitude', 49.252656),
#  ('longitude', -123.067965),
#  ('free_bikes', 5),
#  ('latitude', 49.259469),
#  ('longitude', -123.145718),
#  ('free_bikes', 5),
#  ('latitude', 49.277178),
#  ('longitude', -123.13),
#  ('free_bikes', 3),
#  ('latitude', 49.291597),
#  ('longitude', -123.129158),
#  ('free_bikes', 11),
#  ('latitude', 49.247204),
#  ('longitude', -123.101549),
#  ('free_bikes', 4),
#  ('latitude', 49.2856698),
#  ('longitude', -123.1125432),
#  ('free_bikes', 15),
#  ('latitude', 49.25094),
#  ('longitude', -123.101306),
#  ('free_bikes', 2),
#  ('latitude', 49.280977),
#  ('longitude', -123.035969),
#  ('free_bikes', 15),
#  ('latitude', 49.270783),
#  ('longitude', -123.141564),
#  ('free_bikes', 8)]

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
cb_dataframe = pd.DataFrame(cb_values)
dict1 = {}
for row in cb_dataframe.itertuples():
    if row[1] not in dict1:
        dict1[row[1]] = []

for rows in cb_dataframe.itertuples():
    if rows[1] in dict1:
        dict1[rows[1]].append(rows[2])


cb_df_final = pd.DataFrame.from_dict(dict1)
cb_df_final
# Out:
#       latitude   longitude  free_bikes
# 0    49.262487 -123.114397        17.0
# 1    49.274566 -123.121817        12.0
# 2    49.279764 -123.110154        10.0
# 3    49.260599 -123.113504         4.0
# 4    49.264215 -123.117772         2.0
# ..         ...         ...         ...
# 239  49.247204 -123.101549         4.0
# 240  49.285670 -123.112543        15.0
# 241  49.250940 -123.101306         2.0
# 242  49.280977 -123.035969        15.0
# 243  49.270783 -123.141564         8.0
#
# [244 rows x 3 columns]

# %%
# Created a list of list with latitude and longitude pairs for part 2 in the yelp_foursquare_EDA
cb_lat_long = []
for rows in cb_df_final.itertuples():
    lat_long_list = [rows[1], rows[2]]
    cb_lat_long.append(lat_long_list)
# %store cb_lat_long
#
# Out:
# Stored 'cb_lat_long' (list)
